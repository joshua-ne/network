# %%
from network import *

# %%
config = {'network_folder':'net_topos', 'network':'net14.txt', 'network_bandwidth':10, 'network_delay_low':5, 'network_delay_high':5, \
          'number_of_flows_range':range(1, 20, 1), 'duplicates':10, \
          'flow_bandwidth_low':3, 'flow_bandwidth_high':5, 'flow_delay_low':0, 'flow_delay_high':200, \
          'same_flow_test':False, 'file_output':True, 'output_folder':'outputs', 'file_name_prefix':'low_flow_numbers_'  \
         }

# %%
res = run_experiment(config)
# Out:
# net_topos/net14.txt
# Testing:  1 flows
# pd_mcr:  0.9
# e2e:  0.9
# Testing:  2 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  3 flows
# pd_mcr:  0.9666666666666666
# e2e:  0.9666666666666666
# Testing:  4 flows
# pd_mcr:  0.975
# e2e:  0.975
# Testing:  5 flows
# pd_mcr:  0.9
# e2e:  0.9
# Testing:  6 flows
# pd_mcr:  0.9500000000000002
# e2e:  0.9500000000000002
# Testing:  7 flows
# pd_mcr:  0.9285714285714285
# e2e:  0.9285714285714285
# Testing:  8 flows
# pd_mcr:  0.975
# e2e:  0.975
# Testing:  9 flows
# pd_mcr:  0.9444444444444446
# e2e:  0.9333333333333333
# Testing:  10 flows
# pd_mcr:  0.9200000000000002
# e2e:  0.9200000000000002
# Testing:  11 flows
# pd_mcr:  0.9545454545454545
# e2e:  0.8818181818181818
# Testing:  12 flows
# pd_mcr:  0.9583333333333333
# e2e:  0.9166666666666667
# Testing:  13 flows
# pd_mcr:  0.9230769230769231
# e2e:  0.8538461538461538
# Testing:  14 flows
# pd_mcr:  0.9357142857142857
# e2e:  0.8571428571428571
# Testing:  15 flows
# pd_mcr:  0.9333333333333333
# e2e:  0.8200000000000001
# Testing:  16 flows
# pd_mcr:  0.925
# e2e:  0.81875
# Testing:  17 flows
# pd_mcr:  0.9235294117647059
# e2e:  0.8058823529411765
# Testing:  18 flows
# pd_mcr:  0.888888888888889
# e2e:  0.7777777777777778
# Testing:  19 flows
# pd_mcr:  0.8789473684210527
# e2e:  0.7210526315789474

# %%
res
