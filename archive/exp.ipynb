# %%
from network import *

# %%
# normal
config = {'network_folder':'net_topos', 'network':'net24.txt', 'network_bandwidth':10, 'network_delay_low':5, 'network_delay_high':5, \
          'number_of_flows_range':range(1, 202, 10), 'duplicates':5, \
          'flow_bandwidth_low':3, 'flow_bandwidth_high':5, 'flow_delay_low':0, 'flow_delay_high':200, \
          'same_flow_test':False, 'file_output':True, 'output_folder':'outputs', 'file_name_prefix':''  \
         }

# %%
res = run_experiment(config)
# Out:
# net_topos/net24.txt
# Testing:  1 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  11 flows
# pd_mcr:  0.9636363636363636
# e2e:  0.9636363636363636
# Testing:  21 flows
# pd_mcr:  0.8476190476190476
# e2e:  0.8
# Testing:  31 flows
# pd_mcr:  0.767741935483871
# e2e:  0.6193548387096774
# Testing:  41 flows
# pd_mcr:  0.6292682926829268
# e2e:  0.5024390243902439
# Testing:  51 flows
# pd_mcr:  0.4980392156862745
# e2e:  0.4156862745098039
# Testing:  61 flows
# pd_mcr:  0.46229508196721314
# e2e:  0.37377049180327865
# Testing:  71 flows
# pd_mcr:  0.43661971830985913
# e2e:  0.35492957746478876
# Testing:  81 flows
# pd_mcr:  0.38765432098765434
# e2e:  0.29876543209876544
# Testing:  91 flows
# pd_mcr:  0.356043956043956
# e2e:  0.26373626373626374
# Testing:  101 flows
# pd_mcr:  0.33861386138613864
# e2e:  0.24158415841584158
# Testing:  111 flows
# pd_mcr:  0.2918918918918919
# e2e:  0.22162162162162163
# Testing:  121 flows
# pd_mcr:  0.3041322314049587
# e2e:  0.21322314049586777
# Testing:  131 flows
# pd_mcr:  0.2870229007633588
# e2e:  0.21374045801526717
# Testing:  141 flows
# pd_mcr:  0.275177304964539
# e2e:  0.19007092198581563
# Testing:  151 flows
# pd_mcr:  0.24635761589403976
# e2e:  0.176158940397351
# Testing:  161 flows
# pd_mcr:  0.2496894409937888
# e2e:  0.17888198757763976
# Testing:  171 flows
# pd_mcr:  0.23625730994152044
# e2e:  0.1695906432748538
# Testing:  181 flows
# pd_mcr:  0.2276243093922652
# e2e:  0.1403314917127072
# Testing:  191 flows
# pd_mcr:  0.1968586387434555
# e2e:  0.1424083769633508
# Testing:  201 flows
# pd_mcr:  0.20696517412935322
# e2e:  0.14726368159203979
