# %%
from network import *

# %%
config = {'network_folder':'net_topos', 'network':'net50.txt', 'network_bandwidth':10, 'network_delay_low':5, 'network_delay_high':5, \
          'number_of_flows_range':range(1, 32, 2), 'duplicates':5, \
          'flow_bandwidth_low':3, 'flow_bandwidth_high':5, 'flow_delay_low':0, 'flow_delay_high':200, \
          'same_flow_test':False, 'file_output':True, 'output_folder':'outputs', 'file_name_prefix':'low_flow_numbers_'  \
         }

# %%
res = run_experiment(config)
# Out:
# net_topos/net50.txt
# Testing:  1 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  3 flows
# pd_mcr:  0.8666666666666666
# e2e:  0.8666666666666666
# Testing:  5 flows
# pd_mcr:  0.96
# e2e:  0.96
# Testing:  7 flows
# pd_mcr:  0.9428571428571428
# e2e:  0.9142857142857143
# Testing:  9 flows
# pd_mcr:  0.8222222222222222
# e2e:  0.8222222222222222
# Testing:  11 flows
# pd_mcr:  0.8909090909090909
# e2e:  0.8909090909090909
# Testing:  13 flows
# pd_mcr:  0.9076923076923077
# e2e:  0.923076923076923
# Testing:  15 flows
# pd_mcr:  0.8933333333333333
# e2e:  0.8933333333333333
# Testing:  17 flows
# pd_mcr:  0.8941176470588236
# e2e:  0.8588235294117647
# Testing:  19 flows
# pd_mcr:  0.9052631578947368
# e2e:  0.9052631578947368
# Testing:  21 flows
# pd_mcr:  0.8952380952380953
# e2e:  0.8857142857142856
# Testing:  23 flows
# pd_mcr:  0.8782608695652174
# e2e:  0.8608695652173912
# Testing:  25 flows
# pd_mcr:  0.8959999999999999
# e2e:  0.8560000000000001
# Testing:  27 flows
# pd_mcr:  0.888888888888889
# e2e:  0.8222222222222223
# Testing:  29 flows
# pd_mcr:  0.9103448275862067
# e2e:  0.8
# Testing:  31 flows
# pd_mcr:  0.864516129032258
# e2e:  0.7870967741935484

# %%
res
