# %%
from network import *

# %%
config = {'network_folder':'net_topos', 'network':'net50.txt', 'network_bandwidth':10, 'network_delay_low':5, 'network_delay_high':5, \
          'number_of_flows_range':range(1, 202, 10), 'duplicates':5, \
          'flow_bandwidth_low':3, 'flow_bandwidth_high':5, 'flow_delay_low':0, 'flow_delay_high':200, \
          'same_flow_test':False, 'file_output':True, 'output_folder':'outputs', 'file_name_prefix':''  \
         }

# %%
res = run_experiment(config)
# Out:
# net_topos/net50.txt
# Testing:  1 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  21 flows
# pd_mcr:  0.8571428571428571
# e2e:  0.873015873015873
# Testing:  41 flows
# pd_mcr:  0.8211382113821138
# e2e:  0.6585365853658537
# Testing:  61 flows
# pd_mcr:  0.5956284153005464
# e2e:  0.4863387978142077
# Testing:  81 flows
# pd_mcr:  0.49382716049382713
# e2e:  0.3662551440329218
# Testing:  101 flows
# pd_mcr:  0.41914191419141916
# e2e:  0.33993399339933994
# Testing:  121 flows
# pd_mcr:  0.39669421487603307
# e2e:  0.29201101928374656
# Testing:  141 flows
# pd_mcr:  0.3546099290780142
# e2e:  0.2931442080378251
# Testing:  161 flows
# pd_mcr:  0.3209109730848861
# e2e:  0.2546583850931677
# Testing:  181 flows
# pd_mcr:  0.3001841620626151
# e2e:  0.22283609576427255
# Testing:  201 flows
# pd_mcr:  0.25207296849087896
# e2e:  0.19071310116086235

# %%
res
