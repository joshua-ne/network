# %%
from network import *

# %%
# normal
config = {'network_folder':'net_topos', 'network':'net17.txt', 'network_bandwidth':10, 'network_delay_low':5, 'network_delay_high':5, \
          'number_of_flows_range':range(1, 202, 10), 'duplicates':5, \
          'flow_bandwidth_low':3, 'flow_bandwidth_high':5, 'flow_delay_low':0, 'flow_delay_high':200, \
          'same_flow_test':False, 'file_output':True, 'output_folder':'outputs', 'file_name_prefix':''  \
         }

# %%
res = run_experiment(config)
# Out:
# net_topos/net17.txt
# Testing:  1 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  11 flows
# pd_mcr:  0.909090909090909
# e2e:  0.8545454545454545
# Testing:  21 flows
# pd_mcr:  0.7619047619047619
# e2e:  0.6761904761904762
# Testing:  31 flows
# pd_mcr:  0.6903225806451612
# e2e:  0.5483870967741935
# Testing:  41 flows
# pd_mcr:  0.5756097560975609
# e2e:  0.4536585365853658
# Testing:  51 flows
# pd_mcr:  0.4745098039215686
# e2e:  0.37254901960784315
# Testing:  61 flows
# pd_mcr:  0.4557377049180327
# e2e:  0.3114754098360656
# Testing:  71 flows
# pd_mcr:  0.3690140845070422
# e2e:  0.2619718309859155
# Testing:  81 flows
# pd_mcr:  0.3555555555555555
# e2e:  0.24691358024691357
# Testing:  91 flows
# pd_mcr:  0.33626373626373623
# e2e:  0.23076923076923075
# Testing:  101 flows
# pd_mcr:  0.300990099009901
# e2e:  0.2277227722772277
# Testing:  111 flows
# pd_mcr:  0.28108108108108104
# e2e:  0.19819819819819823
# Testing:  121 flows
# pd_mcr:  0.27107438016528923
# e2e:  0.19008264462809918
# Testing:  131 flows
# pd_mcr:  0.2442748091603053
# e2e:  0.16335877862595422
# Testing:  141 flows
# pd_mcr:  0.22836879432624113
# e2e:  0.15602836879432624
# Testing:  151 flows
# pd_mcr:  0.23046357615894042
# e2e:  0.15761589403973508
# Testing:  161 flows
# pd_mcr:  0.231055900621118
# e2e:  0.14906832298136646
# Testing:  171 flows
# pd_mcr:  0.22573099415204675
# e2e:  0.14619883040935672
# Testing:  181 flows
# pd_mcr:  0.21436464088397794
# e2e:  0.1414364640883978
# Testing:  191 flows
# pd_mcr:  0.19267015706806284
# e2e:  0.12460732984293192
# Testing:  201 flows
# pd_mcr:  0.18407960199004975
# e2e:  0.1263681592039801
