# %%
from network import *

# %%
# low_flow_number_
config = {'network_folder':'net_topos', 'network':'net24.txt', 'network_bandwidth':10, 'network_delay_low':5, 'network_delay_high':5, \
          'number_of_flows_range':range(1, 32, 2), 'duplicates':5, \
          'flow_bandwidth_low':3, 'flow_bandwidth_high':5, 'flow_delay_low':0, 'flow_delay_high':200, \
          'same_flow_test':False, 'file_output':True, 'output_folder':'outputs', 'file_name_prefix':'low_flow_number_'  \
         }

# %%
res = run_experiment(config)
# Out:
# net_topos/net24.txt
# Testing:  1 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  3 flows
# pd_mcr:  0.8666666666666668
# e2e:  0.8666666666666668
# Testing:  5 flows
# pd_mcr:  0.96
# e2e:  0.96
# Testing:  7 flows
# pd_mcr:  0.9428571428571428
# e2e:  0.9428571428571428
# Testing:  9 flows
# pd_mcr:  0.9111111111111111
# e2e:  0.9111111111111111
# Testing:  11 flows
# pd_mcr:  0.9090909090909092
# e2e:  0.9090909090909092
# Testing:  13 flows
# pd_mcr:  0.8923076923076924
# e2e:  0.8615384615384615
# Testing:  15 flows
# pd_mcr:  0.8400000000000001
# e2e:  0.7733333333333334
# Testing:  17 flows
# pd_mcr:  0.9294117647058824
# e2e:  0.8
# Testing:  19 flows
# pd_mcr:  0.9157894736842106
# e2e:  0.8210526315789473
# Testing:  21 flows
# pd_mcr:  0.8
# e2e:  0.6952380952380952
# Testing:  23 flows
# pd_mcr:  0.7913043478260869
# e2e:  0.7043478260869566
# Testing:  25 flows
# pd_mcr:  0.768
# e2e:  0.624
# Testing:  27 flows
# pd_mcr:  0.7925925925925925
# e2e:  0.6592592592592593
# Testing:  29 flows
# pd_mcr:  0.7448275862068965
# e2e:  0.6413793103448275
# Testing:  31 flows
# pd_mcr:  0.7161290322580646
# e2e:  0.5806451612903225
