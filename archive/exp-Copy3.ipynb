# %%
from network import *

# %%
# low_flow_number_
config = {'network_folder':'net_topos', 'network':'net17.txt', 'network_bandwidth':10, 'network_delay_low':5, 'network_delay_high':5, \
          'number_of_flows_range':range(1, 32, 2), 'duplicates':5, \
          'flow_bandwidth_low':3, 'flow_bandwidth_high':5, 'flow_delay_low':0, 'flow_delay_high':200, \
          'same_flow_test':False, 'file_output':True, 'output_folder':'outputs', 'file_name_prefix':'low_flow_number_'  \
         }

# %%
res = run_experiment(config)
# Out:
# net_topos/net17.txt
# Testing:  1 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  3 flows
# pd_mcr:  1.0
# e2e:  1.0
# Testing:  5 flows
# pd_mcr:  0.8800000000000001
# e2e:  0.8800000000000001
# Testing:  7 flows
# pd_mcr:  0.9428571428571428
# e2e:  0.9428571428571428
# Testing:  9 flows
# pd_mcr:  0.9111111111111111
# e2e:  0.888888888888889
# Testing:  11 flows
# pd_mcr:  0.8363636363636363
# e2e:  0.8363636363636363
# Testing:  13 flows
# pd_mcr:  0.9384615384615385
# e2e:  0.876923076923077
# Testing:  15 flows
# pd_mcr:  0.9066666666666666
# e2e:  0.8533333333333333
# Testing:  17 flows
# pd_mcr:  0.8
# e2e:  0.7411764705882353
# Testing:  19 flows
# pd_mcr:  0.7684210526315789
# e2e:  0.6526315789473685
# Testing:  21 flows
# pd_mcr:  0.6952380952380952
# e2e:  0.6380952380952382
# Testing:  23 flows
# pd_mcr:  0.7130434782608697
# e2e:  0.6173913043478261
# Testing:  25 flows
# pd_mcr:  0.688
# e2e:  0.624
# Testing:  27 flows
# pd_mcr:  0.7037037037037036
# e2e:  0.562962962962963
# Testing:  29 flows
# pd_mcr:  0.7034482758620689
# e2e:  0.5862068965517242
# Testing:  31 flows
# pd_mcr:  0.6838709677419356
# e2e:  0.5548387096774193
